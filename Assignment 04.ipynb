# %% [markdown]
# # 1. LeetCode 225

# %%
class MyStack:

    def __init__(self):
        self.__queue1 = []
        self.__queue2 = []

    def push(self, x: int) -> None:
        self.__queue2.append(x)
        while self.__queue1:
            self.__queue2.append(self.__queue1.pop(0))
        self.__queue1, self.__queue2 = self.__queue2, self.__queue1

    def pop(self) -> int:
        return self.__queue1.pop(0)

    def top(self) -> int:
        return self.__queue1[0]

    def empty(self) -> bool:
        return (len(self.__queue1) == 0);


# Your MyStack object will be instantiated and called as such:
# obj = MyStack()
# obj.push(x)
# param_2 = obj.pop()
# param_3 = obj.top()
# param_4 = obj.empty()

# %% [markdown]
# # 2. LeetCode 232

# %%
class MyQueue:

    def __init__(self):
        self.__stack1 = []
        self.__stack2 = []

    def push(self, x: int) -> None:
        self.__stack1.append(x)

    def pop(self) -> int:
        if not self.__stack2:
            while self.__stack1:
                self.__stack2.append(self.__stack1.pop())
        return self.__stack2.pop()

    def peek(self) -> int:
        if not self.__stack2:
            while self.__stack1:
                self.__stack2.append(self.__stack1.pop())
        return self.__stack2[-1]

    def empty(self) -> bool:
        return not self.__stack1 and not self.__stack2


# Your MyQueue object will be instantiated and called as such:
# obj = MyQueue()
# obj.push(x)
# param_2 = obj.pop()
# param_3 = obj.peek()
# param_4 = obj.empty()

# %% [markdown]
# # 3. 교재의 큐 연습문제
#
# ## Problem 01

# %%
class ListQueue:
    def __init__(self):
        self.__queue = []

    def enqueue(self, x):
        self.__queue.insert(0, x) # tail에 삽입 → 리스트 맨 앞에 insert

    def dequeue(self):
        return self.__queue.pop() # front에서 꺼냄 → 리스트 맨 뒤에서 pop

    def front(self):
        return self.__queue[-1] # front 조회 → 리스트[-1]

    def isEmpty(self) -> bool:
        return len(self.__queue) == 0

    def dequeueAll(self):
        self.__queue.clear()

# %%
class ListQueue:
    def __init__(self):
        self.__queue = []

    def enqueue(self, x):
        self.__queue.insert(0, x)  # 맨 앞에 삽입 (tail)

    def dequeue(self):
        return self.__queue.pop()  # 맨 뒤에서 제거 (front)

    def front(self):
        return self.__queue[-1]    # 맨 뒤가 front

    def isEmpty(self) -> bool:
        return len(self.__queue) == 0

    def dequeueAll(self):
        self.__queue.clear()

# %% [markdown]
# ## Problem 02

# %%
class ListQueue:
	def __init__(self):
		self.__queue = []

	def enqueue(self, x):
		self.__queue.append(x)

	def dequeue(self):
		return self.__queue.pop(0)

	def front(self):
		if self.isEmpty():
			return None
		else:
			return self.__queue[0]

	def isEmpty(self) -> bool:
		return (len(self.__queue) == 0);
 
	def dequeueAll(self):
		self.__queue.clear()


def is_w_dollar_w(s):
    q = ListQueue()
    i = 0
    # 첫 번째 w를 큐에 넣는다
    while i < len(s) and s[i] != '$':
        q.enqueue(s[i])
        i += 1
    
    # 만약 $ 기호가 없다면 false
    if i == len(s) or s[i] != '$':
        return False
    
    i += 1  # $ 다음 문자부터 비교
    while i < len(s):
        if q.isEmpty():  # 큐가 먼저 끝났다면 false
            return False
        if s[i] != q.dequeue():  # 문자 다르면 false
            return False
        i += 1
    
    # 모두 비교 후에도 큐가 비어 있어야 함
    return q.isEmpty()

# %% [markdown]
# ## Problem 03

# %%
class ListNode:
	def __init__(self, newItem, nextNode:'ListNode'):
		self.item = newItem
		self.next = nextNode

# 코드 5-1

# %%
class CircularLinkedList:
	def __init__(self):
		self.__tail = ListNode("dummy", None)
		self.__tail.next = self.__tail
		self.__numItems = 0

	def insert(self, i:int, newItem) -> None:
		if (i >= 0 and i <= self.__numItems):
			prev = self.getNode(i - 1)
			newNode = ListNode(newItem, prev.next)
			prev.next = newNode
			if i == self.__numItems:
				self.__tail = newNode
			self.__numItems += 1
		else:
			print("index", i, ": out of bound in insert()") # 필요 시 에러 처리

	def append(self, newItem) -> None:
		newNode = ListNode(newItem, self.__tail.next)
		self.__tail.next = newNode
		self.__tail = newNode
		self.__numItems += 1

	def pop(self, *args):
		# 가변 파라미터. 인자가 없거나 -1이면 마지막 원소로 처리하기 위함. 파이썬 리스트 규칙 만족
		if self.isEmpty():
			return None
		# 인덱스 i 결정
		if len(args) != 0: # pop(k)과 같이 인자가 있으면 i = k 할당
			i = args[0]
		if len(args) == 0 or i == -1:# pop()에 인자가 없거나 pop(-1)이면 i에 맨 끝 인덱스 할당
			i = self.__numItems - 1
		# i번 원소 삭제
		if (i >= 0 and i <= self.__numItems - 1):
			prev = self.getNode(i - 1)
			retItem = prev.next.item
			prev.next = prev.next.next
			if i == self.__numItems - 1:	
				self.__tail = prev		  
			self.__numItems -= 1
			return retItem
		else:
			return None

	def remove(self, x):
		(prev, curr) = self.__findNode(x)
		if curr != None:
			prev.next = curr.next
			if curr == self.__tail:	 
				self.__tail = prev	  
			self.__numItems -= 1
			return x
		else:
			return None

	def get(self, *args):
	# 가변 파라미터. 인자가 없거나 -1이면 마지막 원소로 처리하기 위함. 파이썬 리스트 규칙 만족
		if self.isEmpty():
			return None
		# 인덱스 i 결정
		if len(args) != 0: # pop(k)과 같이 인자가 있으면 i = k 할당
			i = args[0]
		if len(args) == 0 or i == -1:# pop()에 인자가 없거나 pop(-1)이면 i에 맨 끝 인덱스 할당
			i = self.__numItems - 1
		# i번 원소 리턴
		if (i >= 0 and i <= self.__numItems - 1):
			return self.getNode(i).item
		else:
			return None

	def index(self, x) -> int:
		cnt = 0
		for element in self:
			if element == x:
				return cnt
			cnt += 1
		return -12345

	def isEmpty(self) -> bool:
		return self.__numItems == 0

	def size(self) -> int:
		return self.__numItems

	def clear(self):
		self.__tail = ListNode("dummy", None)
		self.__tail.next = self.__tail
		self.__numItems = 0

	def count(self, x) -> int:
		cnt = 0
		for element in self:
			if element == x:
					cnt += 1
		return cnt

	def extend(self, a): # a는 순회 가능한 모든 객체
		for x in a:
			self.append(x)
 
	def copy(self) -> b'CircularLinkedList':
		a = CircularLinkedList()
		for element in self:
			a.append(element)
		return a

	def reverse(self) -> None:
		__head = self.__tail.next  # 더미 헤드
		prev = __head; curr = prev.next; next = curr.next
		curr.next = __head; __head.next = self.__tail; self.__tail = curr
		for i in range(self.__numItems - 1):
			prev = curr; curr = next; next = next.next
			curr.next = prev

	def sort(self) -> None:
		a = []
		for element in self:
			a.append(element)
		a.sort() 
		self.clear()
		for element in a:
			self.append(element)

	def __findNode(self, x) -> (ListNode, ListNode):
		__head = prev = self.__tail.next  # 더미 헤드
		curr = prev.next  # 0번 노드
		while curr != __head:
			if curr.item == x:
				return (prev, curr)
			else:
				prev = curr; curr = curr.next
		return (None, None)
 
	def getNode(self, i:int) -> ListNode:
		curr = self.__tail.next  # 더미 헤드, index: -1
		for index in range(i+1):
			curr = curr.next
		return curr

	def printList(self) -> None:
		for element in self:
			print(element, end = ' ')
		print()

	def __iter__(self):  # generating iterator and return
		return CircularLinkedListIterator(self)

class CircularLinkedListIterator:
	def __init__(self, alist):
		self.__head = alist.getNode(-1)  # 더미 헤드
		self.iterPosition = self.__head.next  # 0번 노드
	def __next__(self):
		if self.iterPosition == self.__head: # 순환 끝
			raise StopIteration
		else: # 현재 원소를 리턴하면서 다음 원소로 이동
			item = self.iterPosition.item
			self.iterPosition = self.iterPosition.next
			return item

# 코드 5-22

# %%
class LinkedQueue:
	def __init__(self):
		self.__queue = CircularLinkedList()

	def enqueue(self, x):
		self.__queue.append(x)

	def dequeue(self):
		return self.__queue.pop(0)	# .pop(0): 리스트의 첫 원소를 삭제한 후 원소 리턴

	def front(self):
		return self.__queue.get(0)	 # .get(0): 리스트의 첫 원소 리턴

	def isEmpty(self) -> bool:
		return self.__queue.isEmpty()
 
	def dequeueAll(self):
		self.__queue.clear()
	def printQueue(self):
		print("Queue from front:", end = ' ')
		for i in range(self.__queue.size()):
			print(self.__queue.get(i), end = ' ')
		print()

# 코드 7-13

# %%
def copy_linked_queue(a: LinkedQueue) -> LinkedQueue:
    b = LinkedQueue()
    temp = LinkedQueue()

    # 1) a에서 꺼내면서 b와 temp에 모두 enqueue
    while not a.isEmpty():
        x = a.dequeue()
        b.enqueue(x)
        temp.enqueue(x)

    # 2) temp에 남은 걸 다시 a에 복원
    while not temp.isEmpty():
        a.enqueue(temp.dequeue())

    return b

# %% [markdown]
# ## Problem 04

# %%
class MStackUsingQueues:

    def __init__(self):
        self.__queue1 = []
        self.__queue2 = []

    def push(self, x: int) -> None:
        self.__queue2.append(x)
        while self.__queue1:
            self.__queue2.append(self.__queue1.pop(0))
        self.__queue1, self.__queue2 = self.__queue2, self.__queue1

    def pop(self) -> int:
        return self.__queue1.pop(0)

# %% [markdown]
# ## Problem 05

# %%
class QueueUsingStacks:
    def __init__(self):
        self.stack1 = []
        self.stack2 = []

    def enqueue(self, x):
        # stack1 -> stack2
        while self.stack1:
            self.stack2.append(self.stack1.pop())
        
        # 새 값 삽입
        self.stack1.append(x)

        # stack2 -> stack1
        while self.stack2:
            self.stack1.append(self.stack2.pop())

    def dequeue(self):
        if not self.stack1:
            return None  # 큐가 비어 있음
        return self.stack1.pop()

# %% [markdown]
# ## Problem 06

# %% [markdown]
# 큐의 사이즈가 n일 때, enqueue()는 append(x)로 구현되고 append()는 tail 노드 뒤에 새 노드를 추가하고 tail 포인터만 이동하므로 수행 시간은 O(1)이다. dequeue()는 pop(0)으로 구현되고 pop(0)은 head 노드(0번째 노드)를 삭제하며, 포인터 이동만으로 삭제가 이루어지므로 O(1)이다.
#
# 따라서 enqueue()와 dequeue()는 모두 수행 시간은 O(1)이다.

# %% [markdown]
# CircularLinkedList는 원형 연결 리스트로 구형되어 있고 head와 tail 포인터를 유지하므로 큐의 사이즈가 n일 때 enqueue()와 dequeue()의 맨앞과 맨뒤 모두 포인터 조작만으로 이루어져 수행 시간은 O(1)이다.
#
# 따라서 Deque의 enqueue()와 dequeue()에서 맨앞과 맨뒤의 수행 시간은 각각 O(1)이다.

# %% [markdown]
# ## Problem 07

# %% [markdown]
# 코드 5-15의 LinkedListBasic은 단일 연결 리스트로 구현되어 있고 head는 유지하지만 tail 포인터는 없기 때문에
# 맨 뒤에 접근하려면 전체 리스트를 순차적으로 탐색해야 한다.
#
# enqueue()에서 맨앞에 할때 head 바로 뒤에 새 노드를 추가하므로 수행시간은 O(1)이다. 맨뒤에 할때는 리스트의 끝까지 이동한 후 추가하므로 마지막 노드를 찾기 위해 __getNode()를 호출해서 수행시간은 O(n)이다. dequeue()에서 맨앞에 할때 head 바로 뒤 노드를 삭제하면 되므로 수행시간은 O(1)이다. 맨뒤에 할때는 리스트의 끝까지 순회한 뒤 삭제해야 하므로 마지막 노드를 찾기 위해 __getNode()를 호출해서 수행시간은 O(n)이다.
#
# 따라서 큐의 사이즈가 n일 때,
# Deque의 enqueue()와 dequeue()에서 맨앞일 때 수행시간은 O(1) 맨뒤일 때 수행시간은 O(n)의 시간이 걸린다.

# %% [markdown]
# ## Problem 08

# %%
class Deque:
    def __init__(self):
        self.__deque = []

    # 맨 앞(=front) 삽입
    def enqueueFront(self, x):
        self.__deque.insert(0, x)

    # 맨 뒤(=back) 삽입
    def enqueueBack(self, x):
        self.__deque.append(x)

    # 맨 앞 제거
    def dequeueFront(self):
        return self.__deque.pop(0)

    # 맨 뒤 제거
    def dequeueBack(self):
        return self.__deque.pop()

    # 맨 앞 조회
    def front(self):
        if self.isEmpty():
            return None
        else:
            return self.__deque[0]

    # 맨 뒤 조회
    def back(self):
        if self.isEmpty():
            return None
        else:
            return self.__deque[-1]

    def isEmpty(self) -> bool:
        return len(self.__deque) == 0

    def dequeueAll(self):
        self.__deque.clear()

    def printDeque(self):
        print("Deque from front:", end=' ')
        for i in self.__deque:
            print(i, end=' ')
        print()
